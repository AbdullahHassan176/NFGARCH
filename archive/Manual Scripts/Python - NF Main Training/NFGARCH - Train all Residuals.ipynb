# %%
# !pip install nflows torch matplotlib numpy
# Out:
# Requirement already satisfied: nflows in c:\users\dullz\appdata\roaming\python\python312\site-packages (0.14)
# Requirement already satisfied: torch in c:\users\dullz\appdata\roaming\python\python312\site-packages (2.4.1)
# Requirement already satisfied: matplotlib in c:\users\dullz\appdata\roaming\python\python312\site-packages (3.10.0)
# Requirement already satisfied: numpy in c:\users\dullz\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: tensorboard in c:\users\dullz\appdata\roaming\python\python312\site-packages (from nflows) (2.17.1)
# Requirement already satisfied: tqdm in c:\users\dullz\anaconda3\lib\site-packages (from nflows) (4.66.5)
# Requirement already satisfied: filelock in c:\users\dullz\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\dullz\anaconda3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in c:\users\dullz\anaconda3\lib\site-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in c:\users\dullz\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\dullz\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\dullz\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\dullz\appdata\roaming\python\python312\site-packages (from torch) (75.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dullz\appdata\roaming\python\python312\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dullz\appdata\roaming\python\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dullz\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dullz\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dullz\appdata\roaming\python\python312\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\dullz\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dullz\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dullz\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\dullz\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dullz\appdata\roaming\python\python312\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\dullz\anaconda3\lib\site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\dullz\appdata\roaming\python\python312\site-packages (from tensorboard->nflows) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\dullz\appdata\roaming\python\python312\site-packages (from tensorboard->nflows) (1.66.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\dullz\appdata\roaming\python\python312\site-packages (from tensorboard->nflows) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\dullz\appdata\roaming\python\python312\site-packages (from tensorboard->nflows) (4.25.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\dullz\appdata\roaming\python\python312\site-packages (from tensorboard->nflows) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\dullz\appdata\roaming\python\python312\site-packages (from tensorboard->nflows) (3.1.3)
# Requirement already satisfied: colorama in c:\users\dullz\appdata\roaming\python\python312\site-packages (from tqdm->nflows) (0.4.6)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import numpy as np
import torch
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
import pandas as pd
from glob import glob
from scipy.stats import ks_2samp, wasserstein_distance, skew, kurtosis
from nflows.distributions import StandardNormal
from nflows.transforms import CompositeTransform, MaskedAffineAutoregressiveTransform
from nflows.flows import Flow

# === Reproducibility
torch.manual_seed(42)
np.random.seed(42)

# === Load price series
df = pd.read_csv("raw (FX + EQ).csv")
usdzar_prices = df["USDZAR"].values
usdzar_returns = np.log(usdzar_prices[1:] / usdzar_prices[:-1])

# === Discover residual files
residuals_dir = "residuals_by_model"
residual_files = glob(os.path.join(residuals_dir, "*", "*.csv"))
print(f"Found {len(residual_files)} residual files.")

def train_nf_on_residuals(file_path, model_key, output_dir="nf_models", epochs=100): #dev epoch
    residuals = pd.read_csv(file_path).values.astype(np.float32)
    residuals = residuals[~np.isnan(residuals)].flatten().reshape(-1, 1)
    residuals_tensor = torch.tensor(residuals, dtype=torch.float32)
    dataset = TensorDataset(residuals_tensor)
    loader = DataLoader(dataset, batch_size=128, shuffle=True)

    transform = CompositeTransform([
        MaskedAffineAutoregressiveTransform(features=1, hidden_features=16)
        for _ in range(5)
    ])
    base_dist = StandardNormal([1])
    flow = Flow(transform, base_dist)

    optimizer = torch.optim.Adam(flow.parameters(), lr=1e-3)
    loss_history = []

    for epoch in range(epochs):
        total_loss = 0.0
        for batch in loader:
            x = batch[0]
            loss = -flow.log_prob(x).mean()
            if torch.isnan(loss):
                print(f"❌ NaN loss encountered at epoch {epoch+1} for {model_key}")
                return None, [], residuals
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        loss_history.append(total_loss / len(loader))
        if (epoch + 1) % 100 == 0 or epoch == 0:
            print(f"[{model_key}] Epoch {epoch+1}: Loss = {loss_history[-1]:.4f}")

    # Save model and loss
    model_subdir = os.path.join(output_dir, model_key)
    os.makedirs(model_subdir, exist_ok=True)
    torch.save(flow.state_dict(), os.path.join(model_subdir, "nf.pth"))
    np.savetxt(os.path.join(model_subdir, "loss_history.txt"), loss_history)

    plt.plot(loss_history)
    plt.title(f"NF Training Loss - {model_key}")
    plt.xlabel("Epoch")
    plt.ylabel("NLL")
    plt.grid()
    os.makedirs("plots", exist_ok=True)
    plt.savefig(f"plots/{model_key}_loss.png")
    plt.close()

    return flow, loss_history, residuals



# === Train and evaluate on all residual files ===
trained_flows = {}
trained_residuals = {}

for file_path in residual_files:
    asset = os.path.basename(os.path.dirname(file_path))        # fx_USDZAR
    model = os.path.splitext(os.path.basename(file_path))[0]    # eGARCH
    model_key = f"{model}_{asset}_residuals_synthetic"
    print(f"\n=== Training NF for {model_key} ===")

    flow, loss_history, resid_array = train_nf_on_residuals(file_path, model_key)
    if flow is None:
        continue

    trained_flows[model_key] = flow
    trained_residuals[model_key] = resid_array

    with torch.no_grad():
        synthetic_resid = flow.sample(len(resid_array)).detach().numpy().flatten()

    # Save synthetic residuals
    synthetic_dir = "nf_generated_residuals"
    os.makedirs(synthetic_dir, exist_ok=True)
    synthetic_path = os.path.join(synthetic_dir, f"{model_key}_synthetic.csv")
    pd.DataFrame({"residual": synthetic_resid}).to_csv(synthetic_path, index=False)
    print(f"✅ Saved synthetic residuals to: {synthetic_path}")
# Out:
# Found 120 residual files.
#
# === Training NF for equity_AMZN_Chrono_Split_residuals_eGARCH_residuals_synthetic ===
# [equity_AMZN_Chrono_Split_residuals_eGARCH_residuals_synthetic] Epoch 1: Loss = 1.5622
# [equity_AMZN_Chrono_Split_residuals_eGARCH_residuals_synthetic] Epoch 100: Loss = 1.5196
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_AMZN_Chrono_Split_residuals_eGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_AMZN_TS_CV_residuals_eGARCH_residuals_synthetic ===
# [equity_AMZN_TS_CV_residuals_eGARCH_residuals_synthetic] Epoch 1: Loss = 1.4822
# [equity_AMZN_TS_CV_residuals_eGARCH_residuals_synthetic] Epoch 100: Loss = 1.4584
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_AMZN_TS_CV_residuals_eGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_CAT_Chrono_Split_residuals_eGARCH_residuals_synthetic ===
# [equity_CAT_Chrono_Split_residuals_eGARCH_residuals_synthetic] Epoch 1: Loss = 1.7117
# [equity_CAT_Chrono_Split_residuals_eGARCH_residuals_synthetic] Epoch 100: Loss = 1.4330
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_CAT_Chrono_Split_residuals_eGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_CAT_TS_CV_residuals_eGARCH_residuals_synthetic ===
# [equity_CAT_TS_CV_residuals_eGARCH_residuals_synthetic] Epoch 1: Loss = 1.4869
# [equity_CAT_TS_CV_residuals_eGARCH_residuals_synthetic] Epoch 100: Loss = 1.4180
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_CAT_TS_CV_residuals_eGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_MSFT_Chrono_Split_residuals_eGARCH_residuals_synthetic ===
# [equity_MSFT_Chrono_Split_residuals_eGARCH_residuals_synthetic] Epoch 1: Loss = 2.4716
# [equity_MSFT_Chrono_Split_residuals_eGARCH_residuals_synthetic] Epoch 100: Loss = 1.4415
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_MSFT_Chrono_Split_residuals_eGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_MSFT_TS_CV_residuals_eGARCH_residuals_synthetic ===
# [equity_MSFT_TS_CV_residuals_eGARCH_residuals_synthetic] Epoch 1: Loss = 1.4596
# [equity_MSFT_TS_CV_residuals_eGARCH_residuals_synthetic] Epoch 100: Loss = 1.4244
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_MSFT_TS_CV_residuals_eGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_NVDA_Chrono_Split_residuals_eGARCH_residuals_synthetic ===
# [equity_NVDA_Chrono_Split_residuals_eGARCH_residuals_synthetic] Epoch 1: Loss = 1.7575
# [equity_NVDA_Chrono_Split_residuals_eGARCH_residuals_synthetic] Epoch 100: Loss = 1.4611
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_NVDA_Chrono_Split_residuals_eGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_NVDA_TS_CV_residuals_eGARCH_residuals_synthetic ===
# [equity_NVDA_TS_CV_residuals_eGARCH_residuals_synthetic] Epoch 1: Loss = 1.5075
# [equity_NVDA_TS_CV_residuals_eGARCH_residuals_synthetic] Epoch 100: Loss = 1.4227
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_NVDA_TS_CV_residuals_eGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_PG_Chrono_Split_residuals_eGARCH_residuals_synthetic ===
# [equity_PG_Chrono_Split_residuals_eGARCH_residuals_synthetic] Epoch 1: Loss = 1.9210
# [equity_PG_Chrono_Split_residuals_eGARCH_residuals_synthetic] Epoch 100: Loss = 1.4107
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_PG_Chrono_Split_residuals_eGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_PG_TS_CV_residuals_eGARCH_residuals_synthetic ===
# [equity_PG_TS_CV_residuals_eGARCH_residuals_synthetic] Epoch 1: Loss = 1.5320
# [equity_PG_TS_CV_residuals_eGARCH_residuals_synthetic] Epoch 100: Loss = 1.4046
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_PG_TS_CV_residuals_eGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_WMT_Chrono_Split_residuals_eGARCH_residuals_synthetic ===
# [equity_WMT_Chrono_Split_residuals_eGARCH_residuals_synthetic] Epoch 1: Loss = 2.4925
# [equity_WMT_Chrono_Split_residuals_eGARCH_residuals_synthetic] Epoch 100: Loss = 1.4205
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_WMT_Chrono_Split_residuals_eGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_WMT_TS_CV_residuals_eGARCH_residuals_synthetic ===
# [equity_WMT_TS_CV_residuals_eGARCH_residuals_synthetic] Epoch 1: Loss = 1.5104
# [equity_WMT_TS_CV_residuals_eGARCH_residuals_synthetic] Epoch 100: Loss = 1.4349
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_WMT_TS_CV_residuals_eGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_EURUSD_Chrono_Split_residuals_eGARCH_residuals_synthetic ===
# [fx_EURUSD_Chrono_Split_residuals_eGARCH_residuals_synthetic] Epoch 1: Loss = 1.7800
# [fx_EURUSD_Chrono_Split_residuals_eGARCH_residuals_synthetic] Epoch 100: Loss = 1.4184
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_EURUSD_Chrono_Split_residuals_eGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_EURUSD_TS_CV_residuals_eGARCH_residuals_synthetic ===
# [fx_EURUSD_TS_CV_residuals_eGARCH_residuals_synthetic] Epoch 1: Loss = 1.4359
# [fx_EURUSD_TS_CV_residuals_eGARCH_residuals_synthetic] Epoch 100: Loss = 1.4069
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_EURUSD_TS_CV_residuals_eGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_EURZAR_Chrono_Split_residuals_eGARCH_residuals_synthetic ===
# [fx_EURZAR_Chrono_Split_residuals_eGARCH_residuals_synthetic] Epoch 1: Loss = 2.4459
# [fx_EURZAR_Chrono_Split_residuals_eGARCH_residuals_synthetic] Epoch 100: Loss = 1.4275
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_EURZAR_Chrono_Split_residuals_eGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_EURZAR_TS_CV_residuals_eGARCH_residuals_synthetic ===
# [fx_EURZAR_TS_CV_residuals_eGARCH_residuals_synthetic] Epoch 1: Loss = 1.4798
# [fx_EURZAR_TS_CV_residuals_eGARCH_residuals_synthetic] Epoch 100: Loss = 1.4214
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_EURZAR_TS_CV_residuals_eGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPCNY_Chrono_Split_residuals_eGARCH_residuals_synthetic ===
# [fx_GBPCNY_Chrono_Split_residuals_eGARCH_residuals_synthetic] Epoch 1: Loss = 2.6217
# [fx_GBPCNY_Chrono_Split_residuals_eGARCH_residuals_synthetic] Epoch 100: Loss = 1.4445
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPCNY_Chrono_Split_residuals_eGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPCNY_TS_CV_residuals_eGARCH_residuals_synthetic ===
# [fx_GBPCNY_TS_CV_residuals_eGARCH_residuals_synthetic] Epoch 1: Loss = 1.5194
# [fx_GBPCNY_TS_CV_residuals_eGARCH_residuals_synthetic] Epoch 100: Loss = 1.4247
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPCNY_TS_CV_residuals_eGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPUSD_Chrono_Split_residuals_eGARCH_residuals_synthetic ===
# [fx_GBPUSD_Chrono_Split_residuals_eGARCH_residuals_synthetic] Epoch 1: Loss = 1.7298
# [fx_GBPUSD_Chrono_Split_residuals_eGARCH_residuals_synthetic] Epoch 100: Loss = 1.4402
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPUSD_Chrono_Split_residuals_eGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPUSD_TS_CV_residuals_eGARCH_residuals_synthetic ===
# [fx_GBPUSD_TS_CV_residuals_eGARCH_residuals_synthetic] Epoch 1: Loss = 1.4736
# [fx_GBPUSD_TS_CV_residuals_eGARCH_residuals_synthetic] Epoch 100: Loss = 1.4127
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPUSD_TS_CV_residuals_eGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPZAR_Chrono_Split_residuals_eGARCH_residuals_synthetic ===
# [fx_GBPZAR_Chrono_Split_residuals_eGARCH_residuals_synthetic] Epoch 1: Loss = 1.6814
# [fx_GBPZAR_Chrono_Split_residuals_eGARCH_residuals_synthetic] Epoch 100: Loss = 1.4265
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPZAR_Chrono_Split_residuals_eGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPZAR_TS_CV_residuals_eGARCH_residuals_synthetic ===
# [fx_GBPZAR_TS_CV_residuals_eGARCH_residuals_synthetic] Epoch 1: Loss = 1.4313
# [fx_GBPZAR_TS_CV_residuals_eGARCH_residuals_synthetic] Epoch 100: Loss = 1.4205
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPZAR_TS_CV_residuals_eGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_USDZAR_Chrono_Split_residuals_eGARCH_residuals_synthetic ===
# [fx_USDZAR_Chrono_Split_residuals_eGARCH_residuals_synthetic] Epoch 1: Loss = 1.6962
# [fx_USDZAR_Chrono_Split_residuals_eGARCH_residuals_synthetic] Epoch 100: Loss = 1.4233
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_USDZAR_Chrono_Split_residuals_eGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_USDZAR_TS_CV_residuals_eGARCH_residuals_synthetic ===
# [fx_USDZAR_TS_CV_residuals_eGARCH_residuals_synthetic] Epoch 1: Loss = 1.4905
# [fx_USDZAR_TS_CV_residuals_eGARCH_residuals_synthetic] Epoch 100: Loss = 1.4208
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_USDZAR_TS_CV_residuals_eGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_AMZN_Chrono_Split_residuals_gjrGARCH_residuals_synthetic ===
# [equity_AMZN_Chrono_Split_residuals_gjrGARCH_residuals_synthetic] Epoch 1: Loss = 1.9897
# [equity_AMZN_Chrono_Split_residuals_gjrGARCH_residuals_synthetic] Epoch 100: Loss = 1.5001
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_AMZN_Chrono_Split_residuals_gjrGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_AMZN_TS_CV_residuals_gjrGARCH_residuals_synthetic ===
# [equity_AMZN_TS_CV_residuals_gjrGARCH_residuals_synthetic] Epoch 1: Loss = 1.5211
# [equity_AMZN_TS_CV_residuals_gjrGARCH_residuals_synthetic] Epoch 100: Loss = 1.4619
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_AMZN_TS_CV_residuals_gjrGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_CAT_Chrono_Split_residuals_gjrGARCH_residuals_synthetic ===
# [equity_CAT_Chrono_Split_residuals_gjrGARCH_residuals_synthetic] Epoch 1: Loss = 1.9168
# [equity_CAT_Chrono_Split_residuals_gjrGARCH_residuals_synthetic] Epoch 100: Loss = 1.4264
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_CAT_Chrono_Split_residuals_gjrGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_CAT_TS_CV_residuals_gjrGARCH_residuals_synthetic ===
# [equity_CAT_TS_CV_residuals_gjrGARCH_residuals_synthetic] Epoch 1: Loss = 1.4695
# [equity_CAT_TS_CV_residuals_gjrGARCH_residuals_synthetic] Epoch 100: Loss = 1.4184
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_CAT_TS_CV_residuals_gjrGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_MSFT_Chrono_Split_residuals_gjrGARCH_residuals_synthetic ===
# [equity_MSFT_Chrono_Split_residuals_gjrGARCH_residuals_synthetic] Epoch 1: Loss = 3.5422
# [equity_MSFT_Chrono_Split_residuals_gjrGARCH_residuals_synthetic] Epoch 100: Loss = 1.4365
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_MSFT_Chrono_Split_residuals_gjrGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_MSFT_TS_CV_residuals_gjrGARCH_residuals_synthetic ===
# [equity_MSFT_TS_CV_residuals_gjrGARCH_residuals_synthetic] Epoch 1: Loss = 1.4625
# [equity_MSFT_TS_CV_residuals_gjrGARCH_residuals_synthetic] Epoch 100: Loss = 1.4253
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_MSFT_TS_CV_residuals_gjrGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_NVDA_Chrono_Split_residuals_gjrGARCH_residuals_synthetic ===
# [equity_NVDA_Chrono_Split_residuals_gjrGARCH_residuals_synthetic] Epoch 1: Loss = 1.5031
# [equity_NVDA_Chrono_Split_residuals_gjrGARCH_residuals_synthetic] Epoch 100: Loss = 1.4791
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_NVDA_Chrono_Split_residuals_gjrGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_NVDA_TS_CV_residuals_gjrGARCH_residuals_synthetic ===
# [equity_NVDA_TS_CV_residuals_gjrGARCH_residuals_synthetic] Epoch 1: Loss = 1.5212
# [equity_NVDA_TS_CV_residuals_gjrGARCH_residuals_synthetic] Epoch 100: Loss = 1.4246
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_NVDA_TS_CV_residuals_gjrGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_PG_Chrono_Split_residuals_gjrGARCH_residuals_synthetic ===
# [equity_PG_Chrono_Split_residuals_gjrGARCH_residuals_synthetic] Epoch 1: Loss = 2.4532
# [equity_PG_Chrono_Split_residuals_gjrGARCH_residuals_synthetic] Epoch 100: Loss = 1.4035
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_PG_Chrono_Split_residuals_gjrGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_PG_TS_CV_residuals_gjrGARCH_residuals_synthetic ===
# [equity_PG_TS_CV_residuals_gjrGARCH_residuals_synthetic] Epoch 1: Loss = 1.4332
# [equity_PG_TS_CV_residuals_gjrGARCH_residuals_synthetic] Epoch 100: Loss = 1.4042
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_PG_TS_CV_residuals_gjrGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_WMT_Chrono_Split_residuals_gjrGARCH_residuals_synthetic ===
# [equity_WMT_Chrono_Split_residuals_gjrGARCH_residuals_synthetic] Epoch 1: Loss = 2.1508
# [equity_WMT_Chrono_Split_residuals_gjrGARCH_residuals_synthetic] Epoch 100: Loss = 1.4198
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_WMT_Chrono_Split_residuals_gjrGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_WMT_TS_CV_residuals_gjrGARCH_residuals_synthetic ===
# [equity_WMT_TS_CV_residuals_gjrGARCH_residuals_synthetic] Epoch 1: Loss = 1.5072
# [equity_WMT_TS_CV_residuals_gjrGARCH_residuals_synthetic] Epoch 100: Loss = 1.4342
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_WMT_TS_CV_residuals_gjrGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_EURUSD_Chrono_Split_residuals_gjrGARCH_residuals_synthetic ===
# [fx_EURUSD_Chrono_Split_residuals_gjrGARCH_residuals_synthetic] Epoch 1: Loss = 2.0156
# [fx_EURUSD_Chrono_Split_residuals_gjrGARCH_residuals_synthetic] Epoch 100: Loss = 1.4253
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_EURUSD_Chrono_Split_residuals_gjrGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_EURUSD_TS_CV_residuals_gjrGARCH_residuals_synthetic ===
# [fx_EURUSD_TS_CV_residuals_gjrGARCH_residuals_synthetic] Epoch 1: Loss = 1.4599
# [fx_EURUSD_TS_CV_residuals_gjrGARCH_residuals_synthetic] Epoch 100: Loss = 1.4246
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_EURUSD_TS_CV_residuals_gjrGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_EURZAR_Chrono_Split_residuals_gjrGARCH_residuals_synthetic ===
# [fx_EURZAR_Chrono_Split_residuals_gjrGARCH_residuals_synthetic] Epoch 1: Loss = 2.6794
# [fx_EURZAR_Chrono_Split_residuals_gjrGARCH_residuals_synthetic] Epoch 100: Loss = 1.4244
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_EURZAR_Chrono_Split_residuals_gjrGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_EURZAR_TS_CV_residuals_gjrGARCH_residuals_synthetic ===
# [fx_EURZAR_TS_CV_residuals_gjrGARCH_residuals_synthetic] Epoch 1: Loss = 1.4725
# [fx_EURZAR_TS_CV_residuals_gjrGARCH_residuals_synthetic] Epoch 100: Loss = 1.4233
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_EURZAR_TS_CV_residuals_gjrGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPCNY_Chrono_Split_residuals_gjrGARCH_residuals_synthetic ===
# [fx_GBPCNY_Chrono_Split_residuals_gjrGARCH_residuals_synthetic] Epoch 1: Loss = 2.9221
# [fx_GBPCNY_Chrono_Split_residuals_gjrGARCH_residuals_synthetic] Epoch 100: Loss = 1.4370
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPCNY_Chrono_Split_residuals_gjrGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPCNY_TS_CV_residuals_gjrGARCH_residuals_synthetic ===
# [fx_GBPCNY_TS_CV_residuals_gjrGARCH_residuals_synthetic] Epoch 1: Loss = 1.4651
# [fx_GBPCNY_TS_CV_residuals_gjrGARCH_residuals_synthetic] Epoch 100: Loss = 1.4281
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPCNY_TS_CV_residuals_gjrGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPUSD_Chrono_Split_residuals_gjrGARCH_residuals_synthetic ===
# [fx_GBPUSD_Chrono_Split_residuals_gjrGARCH_residuals_synthetic] Epoch 1: Loss = 3.0306
# [fx_GBPUSD_Chrono_Split_residuals_gjrGARCH_residuals_synthetic] Epoch 100: Loss = 1.4343
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPUSD_Chrono_Split_residuals_gjrGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPUSD_TS_CV_residuals_gjrGARCH_residuals_synthetic ===
# [fx_GBPUSD_TS_CV_residuals_gjrGARCH_residuals_synthetic] Epoch 1: Loss = 1.5791
# [fx_GBPUSD_TS_CV_residuals_gjrGARCH_residuals_synthetic] Epoch 100: Loss = 1.4267
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPUSD_TS_CV_residuals_gjrGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPZAR_Chrono_Split_residuals_gjrGARCH_residuals_synthetic ===
# [fx_GBPZAR_Chrono_Split_residuals_gjrGARCH_residuals_synthetic] Epoch 1: Loss = 1.4985
# [fx_GBPZAR_Chrono_Split_residuals_gjrGARCH_residuals_synthetic] Epoch 100: Loss = 1.4224
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPZAR_Chrono_Split_residuals_gjrGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPZAR_TS_CV_residuals_gjrGARCH_residuals_synthetic ===
# [fx_GBPZAR_TS_CV_residuals_gjrGARCH_residuals_synthetic] Epoch 1: Loss = 1.4981
# [fx_GBPZAR_TS_CV_residuals_gjrGARCH_residuals_synthetic] Epoch 100: Loss = 1.4248
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPZAR_TS_CV_residuals_gjrGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_USDZAR_Chrono_Split_residuals_gjrGARCH_residuals_synthetic ===
# [fx_USDZAR_Chrono_Split_residuals_gjrGARCH_residuals_synthetic] Epoch 1: Loss = 2.1880
# [fx_USDZAR_Chrono_Split_residuals_gjrGARCH_residuals_synthetic] Epoch 100: Loss = 1.4230
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_USDZAR_Chrono_Split_residuals_gjrGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_USDZAR_TS_CV_residuals_gjrGARCH_residuals_synthetic ===
# [fx_USDZAR_TS_CV_residuals_gjrGARCH_residuals_synthetic] Epoch 1: Loss = 1.4521
# [fx_USDZAR_TS_CV_residuals_gjrGARCH_residuals_synthetic] Epoch 100: Loss = 1.4223
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_USDZAR_TS_CV_residuals_gjrGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_AMZN_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic ===
# [equity_AMZN_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic] Epoch 1: Loss = 1.6784
# [equity_AMZN_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic] Epoch 100: Loss = 1.4317
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_AMZN_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_AMZN_TS_CV_residuals_sGARCH_norm_residuals_synthetic ===
# [equity_AMZN_TS_CV_residuals_sGARCH_norm_residuals_synthetic] Epoch 1: Loss = 1.4579
# [equity_AMZN_TS_CV_residuals_sGARCH_norm_residuals_synthetic] Epoch 100: Loss = 1.4300
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_AMZN_TS_CV_residuals_sGARCH_norm_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_CAT_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic ===
# [equity_CAT_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic] Epoch 1: Loss = 1.7206
# [equity_CAT_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic] Epoch 100: Loss = 1.4205
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_CAT_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_CAT_TS_CV_residuals_sGARCH_norm_residuals_synthetic ===
# [equity_CAT_TS_CV_residuals_sGARCH_norm_residuals_synthetic] Epoch 1: Loss = 1.5254
# [equity_CAT_TS_CV_residuals_sGARCH_norm_residuals_synthetic] Epoch 100: Loss = 1.4252
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_CAT_TS_CV_residuals_sGARCH_norm_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_MSFT_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic ===
# [equity_MSFT_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic] Epoch 1: Loss = 1.9917
# [equity_MSFT_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic] Epoch 100: Loss = 1.4219
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_MSFT_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_MSFT_TS_CV_residuals_sGARCH_norm_residuals_synthetic ===
# [equity_MSFT_TS_CV_residuals_sGARCH_norm_residuals_synthetic] Epoch 1: Loss = 1.4737
# [equity_MSFT_TS_CV_residuals_sGARCH_norm_residuals_synthetic] Epoch 100: Loss = 1.4207
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_MSFT_TS_CV_residuals_sGARCH_norm_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_NVDA_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic ===
# [equity_NVDA_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic] Epoch 1: Loss = 1.6505
# [equity_NVDA_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic] Epoch 100: Loss = 1.4222
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_NVDA_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_NVDA_TS_CV_residuals_sGARCH_norm_residuals_synthetic ===
# [equity_NVDA_TS_CV_residuals_sGARCH_norm_residuals_synthetic] Epoch 1: Loss = 1.4272
# [equity_NVDA_TS_CV_residuals_sGARCH_norm_residuals_synthetic] Epoch 100: Loss = 1.4144
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_NVDA_TS_CV_residuals_sGARCH_norm_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_PG_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic ===
# [equity_PG_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic] Epoch 1: Loss = 1.7001
# [equity_PG_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic] Epoch 100: Loss = 1.4204
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_PG_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_PG_TS_CV_residuals_sGARCH_norm_residuals_synthetic ===
# [equity_PG_TS_CV_residuals_sGARCH_norm_residuals_synthetic] Epoch 1: Loss = 1.5829
# [equity_PG_TS_CV_residuals_sGARCH_norm_residuals_synthetic] Epoch 100: Loss = 1.4182
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_PG_TS_CV_residuals_sGARCH_norm_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_WMT_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic ===
# [equity_WMT_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic] Epoch 1: Loss = 1.6673
# [equity_WMT_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic] Epoch 100: Loss = 1.4229
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_WMT_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_WMT_TS_CV_residuals_sGARCH_norm_residuals_synthetic ===
# [equity_WMT_TS_CV_residuals_sGARCH_norm_residuals_synthetic] Epoch 1: Loss = 1.4801
# [equity_WMT_TS_CV_residuals_sGARCH_norm_residuals_synthetic] Epoch 100: Loss = 1.4251
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_WMT_TS_CV_residuals_sGARCH_norm_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_EURUSD_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic ===
# [fx_EURUSD_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic] Epoch 1: Loss = 2.4892
# [fx_EURUSD_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic] Epoch 100: Loss = 1.4273
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_EURUSD_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_EURUSD_TS_CV_residuals_sGARCH_norm_residuals_synthetic ===
# [fx_EURUSD_TS_CV_residuals_sGARCH_norm_residuals_synthetic] Epoch 1: Loss = 1.5408
# [fx_EURUSD_TS_CV_residuals_sGARCH_norm_residuals_synthetic] Epoch 100: Loss = 1.4275
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_EURUSD_TS_CV_residuals_sGARCH_norm_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_EURZAR_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic ===
# [fx_EURZAR_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic] Epoch 1: Loss = 1.5539
# [fx_EURZAR_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic] Epoch 100: Loss = 1.4202
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_EURZAR_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_EURZAR_TS_CV_residuals_sGARCH_norm_residuals_synthetic ===
# [fx_EURZAR_TS_CV_residuals_sGARCH_norm_residuals_synthetic] Epoch 1: Loss = 1.4681
# [fx_EURZAR_TS_CV_residuals_sGARCH_norm_residuals_synthetic] Epoch 100: Loss = 1.4255
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_EURZAR_TS_CV_residuals_sGARCH_norm_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPCNY_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic ===
# [fx_GBPCNY_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic] Epoch 1: Loss = 2.1270
# [fx_GBPCNY_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic] Epoch 100: Loss = 1.4187
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPCNY_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPCNY_TS_CV_residuals_sGARCH_norm_residuals_synthetic ===
# [fx_GBPCNY_TS_CV_residuals_sGARCH_norm_residuals_synthetic] Epoch 1: Loss = 1.4717
# [fx_GBPCNY_TS_CV_residuals_sGARCH_norm_residuals_synthetic] Epoch 100: Loss = 1.4225
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPCNY_TS_CV_residuals_sGARCH_norm_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPUSD_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic ===
# [fx_GBPUSD_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic] Epoch 1: Loss = 1.6283
# [fx_GBPUSD_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic] Epoch 100: Loss = 1.4191
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPUSD_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPUSD_TS_CV_residuals_sGARCH_norm_residuals_synthetic ===
# [fx_GBPUSD_TS_CV_residuals_sGARCH_norm_residuals_synthetic] Epoch 1: Loss = 1.4339
# [fx_GBPUSD_TS_CV_residuals_sGARCH_norm_residuals_synthetic] Epoch 100: Loss = 1.4262
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPUSD_TS_CV_residuals_sGARCH_norm_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPZAR_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic ===
# [fx_GBPZAR_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic] Epoch 1: Loss = 2.1617
# [fx_GBPZAR_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic] Epoch 100: Loss = 1.4194
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPZAR_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPZAR_TS_CV_residuals_sGARCH_norm_residuals_synthetic ===
# [fx_GBPZAR_TS_CV_residuals_sGARCH_norm_residuals_synthetic] Epoch 1: Loss = 1.5270
# [fx_GBPZAR_TS_CV_residuals_sGARCH_norm_residuals_synthetic] Epoch 100: Loss = 1.4228
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPZAR_TS_CV_residuals_sGARCH_norm_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_USDZAR_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic ===
# [fx_USDZAR_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic] Epoch 1: Loss = 1.5774
# [fx_USDZAR_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic] Epoch 100: Loss = 1.4215
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_USDZAR_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_USDZAR_TS_CV_residuals_sGARCH_norm_residuals_synthetic ===
# [fx_USDZAR_TS_CV_residuals_sGARCH_norm_residuals_synthetic] Epoch 1: Loss = 1.4922
# [fx_USDZAR_TS_CV_residuals_sGARCH_norm_residuals_synthetic] Epoch 100: Loss = 1.4206
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_USDZAR_TS_CV_residuals_sGARCH_norm_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_AMZN_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic ===
# [equity_AMZN_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic] Epoch 1: Loss = 2.0057
# [equity_AMZN_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic] Epoch 100: Loss = 1.4727
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_AMZN_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_AMZN_TS_CV_residuals_sGARCH_sstd_residuals_synthetic ===
# [equity_AMZN_TS_CV_residuals_sGARCH_sstd_residuals_synthetic] Epoch 1: Loss = 1.5017
# [equity_AMZN_TS_CV_residuals_sGARCH_sstd_residuals_synthetic] Epoch 100: Loss = 1.4492
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_AMZN_TS_CV_residuals_sGARCH_sstd_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_CAT_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic ===
# [equity_CAT_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic] Epoch 1: Loss = 2.4320
# [equity_CAT_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic] Epoch 100: Loss = 1.4260
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_CAT_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_CAT_TS_CV_residuals_sGARCH_sstd_residuals_synthetic ===
# [equity_CAT_TS_CV_residuals_sGARCH_sstd_residuals_synthetic] Epoch 1: Loss = 1.5005
# [equity_CAT_TS_CV_residuals_sGARCH_sstd_residuals_synthetic] Epoch 100: Loss = 1.4179
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_CAT_TS_CV_residuals_sGARCH_sstd_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_MSFT_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic ===
# [equity_MSFT_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic] Epoch 1: Loss = 3.5443
# [equity_MSFT_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic] Epoch 100: Loss = 1.4373
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_MSFT_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_MSFT_TS_CV_residuals_sGARCH_sstd_residuals_synthetic ===
# [equity_MSFT_TS_CV_residuals_sGARCH_sstd_residuals_synthetic] Epoch 1: Loss = 1.4399
# [equity_MSFT_TS_CV_residuals_sGARCH_sstd_residuals_synthetic] Epoch 100: Loss = 1.4177
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_MSFT_TS_CV_residuals_sGARCH_sstd_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_NVDA_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic ===
# [equity_NVDA_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic] Epoch 1: Loss = 2.7092
# [equity_NVDA_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic] Epoch 100: Loss = 1.4611
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_NVDA_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_NVDA_TS_CV_residuals_sGARCH_sstd_residuals_synthetic ===
# [equity_NVDA_TS_CV_residuals_sGARCH_sstd_residuals_synthetic] Epoch 1: Loss = 1.4704
# [equity_NVDA_TS_CV_residuals_sGARCH_sstd_residuals_synthetic] Epoch 100: Loss = 1.4148
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_NVDA_TS_CV_residuals_sGARCH_sstd_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_PG_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic ===
# [equity_PG_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic] Epoch 1: Loss = 1.9221
# [equity_PG_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic] Epoch 100: Loss = 1.3999
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_PG_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_PG_TS_CV_residuals_sGARCH_sstd_residuals_synthetic ===
# [equity_PG_TS_CV_residuals_sGARCH_sstd_residuals_synthetic] Epoch 1: Loss = 1.4576
# [equity_PG_TS_CV_residuals_sGARCH_sstd_residuals_synthetic] Epoch 100: Loss = 1.4015
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_PG_TS_CV_residuals_sGARCH_sstd_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_WMT_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic ===
# [equity_WMT_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic] Epoch 1: Loss = 2.7915
# [equity_WMT_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic] Epoch 100: Loss = 1.4180
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_WMT_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_WMT_TS_CV_residuals_sGARCH_sstd_residuals_synthetic ===
# [equity_WMT_TS_CV_residuals_sGARCH_sstd_residuals_synthetic] Epoch 1: Loss = 1.4588
# [equity_WMT_TS_CV_residuals_sGARCH_sstd_residuals_synthetic] Epoch 100: Loss = 1.4330
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_WMT_TS_CV_residuals_sGARCH_sstd_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_EURUSD_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic ===
# [fx_EURUSD_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic] Epoch 1: Loss = 2.2557
# [fx_EURUSD_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic] Epoch 100: Loss = 1.4200
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_EURUSD_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_EURUSD_TS_CV_residuals_sGARCH_sstd_residuals_synthetic ===
# [fx_EURUSD_TS_CV_residuals_sGARCH_sstd_residuals_synthetic] Epoch 1: Loss = 1.4866
# [fx_EURUSD_TS_CV_residuals_sGARCH_sstd_residuals_synthetic] Epoch 100: Loss = 1.4240
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_EURUSD_TS_CV_residuals_sGARCH_sstd_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_EURZAR_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic ===
# [fx_EURZAR_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic] Epoch 1: Loss = 1.7240
# [fx_EURZAR_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic] Epoch 100: Loss = 1.4286
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_EURZAR_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_EURZAR_TS_CV_residuals_sGARCH_sstd_residuals_synthetic ===
# [fx_EURZAR_TS_CV_residuals_sGARCH_sstd_residuals_synthetic] Epoch 1: Loss = 1.4819
# [fx_EURZAR_TS_CV_residuals_sGARCH_sstd_residuals_synthetic] Epoch 100: Loss = 1.4267
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_EURZAR_TS_CV_residuals_sGARCH_sstd_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPCNY_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic ===
# [fx_GBPCNY_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic] Epoch 1: Loss = 2.0299
# [fx_GBPCNY_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic] Epoch 100: Loss = 1.4342
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPCNY_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPCNY_TS_CV_residuals_sGARCH_sstd_residuals_synthetic ===
# [fx_GBPCNY_TS_CV_residuals_sGARCH_sstd_residuals_synthetic] Epoch 1: Loss = 1.4867
# [fx_GBPCNY_TS_CV_residuals_sGARCH_sstd_residuals_synthetic] Epoch 100: Loss = 1.4279
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPCNY_TS_CV_residuals_sGARCH_sstd_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPUSD_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic ===
# [fx_GBPUSD_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic] Epoch 1: Loss = 2.0994
# [fx_GBPUSD_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic] Epoch 100: Loss = 1.4312
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPUSD_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPUSD_TS_CV_residuals_sGARCH_sstd_residuals_synthetic ===
# [fx_GBPUSD_TS_CV_residuals_sGARCH_sstd_residuals_synthetic] Epoch 1: Loss = 1.4709
# [fx_GBPUSD_TS_CV_residuals_sGARCH_sstd_residuals_synthetic] Epoch 100: Loss = 1.4277
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPUSD_TS_CV_residuals_sGARCH_sstd_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPZAR_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic ===
# [fx_GBPZAR_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic] Epoch 1: Loss = 2.5888
# [fx_GBPZAR_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic] Epoch 100: Loss = 1.4255
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPZAR_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPZAR_TS_CV_residuals_sGARCH_sstd_residuals_synthetic ===
# [fx_GBPZAR_TS_CV_residuals_sGARCH_sstd_residuals_synthetic] Epoch 1: Loss = 1.4678
# [fx_GBPZAR_TS_CV_residuals_sGARCH_sstd_residuals_synthetic] Epoch 100: Loss = 1.4244
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPZAR_TS_CV_residuals_sGARCH_sstd_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_USDZAR_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic ===
# [fx_USDZAR_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic] Epoch 1: Loss = 2.3924
# [fx_USDZAR_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic] Epoch 100: Loss = 1.4264
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_USDZAR_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_USDZAR_TS_CV_residuals_sGARCH_sstd_residuals_synthetic ===
# [fx_USDZAR_TS_CV_residuals_sGARCH_sstd_residuals_synthetic] Epoch 1: Loss = 1.4783
# [fx_USDZAR_TS_CV_residuals_sGARCH_sstd_residuals_synthetic] Epoch 100: Loss = 1.4248
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_USDZAR_TS_CV_residuals_sGARCH_sstd_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_AMZN_Chrono_Split_residuals_TGARCH_residuals_synthetic ===
# [equity_AMZN_Chrono_Split_residuals_TGARCH_residuals_synthetic] Epoch 1: Loss = 2.1613
# [equity_AMZN_Chrono_Split_residuals_TGARCH_residuals_synthetic] Epoch 100: Loss = 1.5267
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_AMZN_Chrono_Split_residuals_TGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_AMZN_TS_CV_residuals_TGARCH_residuals_synthetic ===
# [equity_AMZN_TS_CV_residuals_TGARCH_residuals_synthetic] Epoch 1: Loss = 1.4906
# [equity_AMZN_TS_CV_residuals_TGARCH_residuals_synthetic] Epoch 100: Loss = 1.4746
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_AMZN_TS_CV_residuals_TGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_CAT_Chrono_Split_residuals_TGARCH_residuals_synthetic ===
# [equity_CAT_Chrono_Split_residuals_TGARCH_residuals_synthetic] Epoch 1: Loss = 2.0449
# [equity_CAT_Chrono_Split_residuals_TGARCH_residuals_synthetic] Epoch 100: Loss = 1.4289
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_CAT_Chrono_Split_residuals_TGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_CAT_TS_CV_residuals_TGARCH_residuals_synthetic ===
# [equity_CAT_TS_CV_residuals_TGARCH_residuals_synthetic] Epoch 1: Loss = 1.4528
# [equity_CAT_TS_CV_residuals_TGARCH_residuals_synthetic] Epoch 100: Loss = 1.4254
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_CAT_TS_CV_residuals_TGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_MSFT_Chrono_Split_residuals_TGARCH_residuals_synthetic ===
# [equity_MSFT_Chrono_Split_residuals_TGARCH_residuals_synthetic] Epoch 1: Loss = 1.7415
# [equity_MSFT_Chrono_Split_residuals_TGARCH_residuals_synthetic] Epoch 100: Loss = 1.4498
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_MSFT_Chrono_Split_residuals_TGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_MSFT_TS_CV_residuals_TGARCH_residuals_synthetic ===
# [equity_MSFT_TS_CV_residuals_TGARCH_residuals_synthetic] Epoch 1: Loss = 1.4859
# [equity_MSFT_TS_CV_residuals_TGARCH_residuals_synthetic] Epoch 100: Loss = 1.4338
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_MSFT_TS_CV_residuals_TGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_NVDA_Chrono_Split_residuals_TGARCH_residuals_synthetic ===
# [equity_NVDA_Chrono_Split_residuals_TGARCH_residuals_synthetic] Epoch 1: Loss = 2.1954
# [equity_NVDA_Chrono_Split_residuals_TGARCH_residuals_synthetic] Epoch 100: Loss = 1.4736
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_NVDA_Chrono_Split_residuals_TGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_NVDA_TS_CV_residuals_TGARCH_residuals_synthetic ===
# [equity_NVDA_TS_CV_residuals_TGARCH_residuals_synthetic] Epoch 1: Loss = 1.4468
# [equity_NVDA_TS_CV_residuals_TGARCH_residuals_synthetic] Epoch 100: Loss = 1.4305
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_NVDA_TS_CV_residuals_TGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_PG_Chrono_Split_residuals_TGARCH_residuals_synthetic ===
# [equity_PG_Chrono_Split_residuals_TGARCH_residuals_synthetic] Epoch 1: Loss = 1.8386
# [equity_PG_Chrono_Split_residuals_TGARCH_residuals_synthetic] Epoch 100: Loss = 1.4168
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_PG_Chrono_Split_residuals_TGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_PG_TS_CV_residuals_TGARCH_residuals_synthetic ===
# [equity_PG_TS_CV_residuals_TGARCH_residuals_synthetic] Epoch 1: Loss = 1.4719
# [equity_PG_TS_CV_residuals_TGARCH_residuals_synthetic] Epoch 100: Loss = 1.4122
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_PG_TS_CV_residuals_TGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_WMT_Chrono_Split_residuals_TGARCH_residuals_synthetic ===
# [equity_WMT_Chrono_Split_residuals_TGARCH_residuals_synthetic] Epoch 1: Loss = 1.5327
# [equity_WMT_Chrono_Split_residuals_TGARCH_residuals_synthetic] Epoch 100: Loss = 1.4232
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_WMT_Chrono_Split_residuals_TGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for equity_WMT_TS_CV_residuals_TGARCH_residuals_synthetic ===
# [equity_WMT_TS_CV_residuals_TGARCH_residuals_synthetic] Epoch 1: Loss = 1.5221
# [equity_WMT_TS_CV_residuals_TGARCH_residuals_synthetic] Epoch 100: Loss = 1.4400
# ✅ Saved synthetic residuals to: nf_generated_residuals\equity_WMT_TS_CV_residuals_TGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_EURUSD_Chrono_Split_residuals_TGARCH_residuals_synthetic ===
# [fx_EURUSD_Chrono_Split_residuals_TGARCH_residuals_synthetic] Epoch 1: Loss = 1.8021
# [fx_EURUSD_Chrono_Split_residuals_TGARCH_residuals_synthetic] Epoch 100: Loss = 1.4204
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_EURUSD_Chrono_Split_residuals_TGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_EURUSD_TS_CV_residuals_TGARCH_residuals_synthetic ===
# [fx_EURUSD_TS_CV_residuals_TGARCH_residuals_synthetic] Epoch 1: Loss = 1.4511
# [fx_EURUSD_TS_CV_residuals_TGARCH_residuals_synthetic] Epoch 100: Loss = 1.4186
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_EURUSD_TS_CV_residuals_TGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_EURZAR_Chrono_Split_residuals_TGARCH_residuals_synthetic ===
# [fx_EURZAR_Chrono_Split_residuals_TGARCH_residuals_synthetic] Epoch 1: Loss = 2.1404
# [fx_EURZAR_Chrono_Split_residuals_TGARCH_residuals_synthetic] Epoch 100: Loss = 1.4235
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_EURZAR_Chrono_Split_residuals_TGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_EURZAR_TS_CV_residuals_TGARCH_residuals_synthetic ===
# [fx_EURZAR_TS_CV_residuals_TGARCH_residuals_synthetic] Epoch 1: Loss = 1.4685
# [fx_EURZAR_TS_CV_residuals_TGARCH_residuals_synthetic] Epoch 100: Loss = 1.4217
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_EURZAR_TS_CV_residuals_TGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPCNY_Chrono_Split_residuals_TGARCH_residuals_synthetic ===
# [fx_GBPCNY_Chrono_Split_residuals_TGARCH_residuals_synthetic] Epoch 1: Loss = 2.1497
# [fx_GBPCNY_Chrono_Split_residuals_TGARCH_residuals_synthetic] Epoch 100: Loss = 1.4482
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPCNY_Chrono_Split_residuals_TGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPCNY_TS_CV_residuals_TGARCH_residuals_synthetic ===
# [fx_GBPCNY_TS_CV_residuals_TGARCH_residuals_synthetic] Epoch 1: Loss = 1.4841
# [fx_GBPCNY_TS_CV_residuals_TGARCH_residuals_synthetic] Epoch 100: Loss = 1.4309
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPCNY_TS_CV_residuals_TGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPUSD_Chrono_Split_residuals_TGARCH_residuals_synthetic ===
# [fx_GBPUSD_Chrono_Split_residuals_TGARCH_residuals_synthetic] Epoch 1: Loss = 1.6671
# [fx_GBPUSD_Chrono_Split_residuals_TGARCH_residuals_synthetic] Epoch 100: Loss = 1.4456
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPUSD_Chrono_Split_residuals_TGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPUSD_TS_CV_residuals_TGARCH_residuals_synthetic ===
# [fx_GBPUSD_TS_CV_residuals_TGARCH_residuals_synthetic] Epoch 1: Loss = 1.5591
# [fx_GBPUSD_TS_CV_residuals_TGARCH_residuals_synthetic] Epoch 100: Loss = 1.4275
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPUSD_TS_CV_residuals_TGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPZAR_Chrono_Split_residuals_TGARCH_residuals_synthetic ===
# [fx_GBPZAR_Chrono_Split_residuals_TGARCH_residuals_synthetic] Epoch 1: Loss = 2.5023
# [fx_GBPZAR_Chrono_Split_residuals_TGARCH_residuals_synthetic] Epoch 100: Loss = 1.4279
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPZAR_Chrono_Split_residuals_TGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_GBPZAR_TS_CV_residuals_TGARCH_residuals_synthetic ===
# [fx_GBPZAR_TS_CV_residuals_TGARCH_residuals_synthetic] Epoch 1: Loss = 1.4552
# [fx_GBPZAR_TS_CV_residuals_TGARCH_residuals_synthetic] Epoch 100: Loss = 1.4230
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_GBPZAR_TS_CV_residuals_TGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_USDZAR_Chrono_Split_residuals_TGARCH_residuals_synthetic ===
# [fx_USDZAR_Chrono_Split_residuals_TGARCH_residuals_synthetic] Epoch 1: Loss = 2.3308
# [fx_USDZAR_Chrono_Split_residuals_TGARCH_residuals_synthetic] Epoch 100: Loss = 1.4256
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_USDZAR_Chrono_Split_residuals_TGARCH_residuals_synthetic_synthetic.csv
#
# === Training NF for fx_USDZAR_TS_CV_residuals_TGARCH_residuals_synthetic ===
# [fx_USDZAR_TS_CV_residuals_TGARCH_residuals_synthetic] Epoch 1: Loss = 1.5566
# [fx_USDZAR_TS_CV_residuals_TGARCH_residuals_synthetic] Epoch 100: Loss = 1.4231
# ✅ Saved synthetic residuals to: nf_generated_residuals\fx_USDZAR_TS_CV_residuals_TGARCH_residuals_synthetic_synthetic.csv

# %%
def find_matching_model_key(trained_dict, asset, model_config):
    for key in trained_dict.keys():
        if asset in key and model_config in key:
            return key
    raise KeyError(f"No model found for asset={asset}, model={model_config}")

print("\nAvailable model keys:")
for k in trained_flows.keys():
    print("-", k)

def evaluate_synthetic_residuals(asset, model_config, trained_flows, trained_residuals, real_prices, real_returns):
    model_key = find_matching_model_key(trained_flows, asset, model_config)
    flow = trained_flows[model_key]
    residuals = trained_residuals[model_key].flatten()

    with torch.no_grad():
        synthetic_residuals = flow.sample(len(residuals)).detach().numpy().flatten()

    # Residual comparison
    plt.hist(residuals, bins=60, alpha=0.6, label="Original")
    plt.hist(synthetic_residuals, bins=60, alpha=0.6, label="Synthetic")
    plt.legend()
    plt.title(f"Residual Distribution: {model_key}")
    plt.savefig(f"plots/{model_key}_residual_comparison.png")
    plt.close()

    # Price simulation
    synthetic_returns = synthetic_residuals * np.std(real_returns)
    synthetic_prices = real_prices[0] * np.cumprod(np.exp(synthetic_returns))
    synthetic_prices = synthetic_prices[:len(real_prices)]

    plt.figure(figsize=(10, 5))
    plt.plot(real_prices, label="Real USDZAR")
    plt.plot(synthetic_prices, label="Synthetic NF", linestyle="--")
    plt.legend()
    plt.title(f"{asset} - Real vs Synthetic Price Path")
    plt.savefig(f"plots/{model_key}_price_comparison.png")
    plt.close()

    # Evaluation metrics
    metrics = {
        "KS Distance": ks_2samp(real_returns, synthetic_returns).statistic,
        "Wasserstein Distance": wasserstein_distance(real_returns, synthetic_returns),
        "Skewness (Real)": skew(real_returns),
        "Skewness (Synthetic)": skew(synthetic_returns),
        "Kurtosis (Real)": kurtosis(real_returns),
        "Kurtosis (Synthetic)": kurtosis(synthetic_returns)
    }

    print(f"\n📊 Metrics for {model_key}:")
    for k, v in metrics.items():
        print(f"{k}: {v:.5f}")

    return synthetic_returns

# === Example usage: USDZAR, eGARCH
evaluate_synthetic_residuals("USDZAR", "eGARCH", trained_flows, trained_residuals, usdzar_prices, usdzar_returns)
# Out:
# Available model keys:
# - equity_AMZN_Chrono_Split_residuals_eGARCH_residuals_synthetic
# - equity_AMZN_TS_CV_residuals_eGARCH_residuals_synthetic
# - equity_CAT_Chrono_Split_residuals_eGARCH_residuals_synthetic
# - equity_CAT_TS_CV_residuals_eGARCH_residuals_synthetic
# - equity_MSFT_Chrono_Split_residuals_eGARCH_residuals_synthetic
# - equity_MSFT_TS_CV_residuals_eGARCH_residuals_synthetic
# - equity_NVDA_Chrono_Split_residuals_eGARCH_residuals_synthetic
# - equity_NVDA_TS_CV_residuals_eGARCH_residuals_synthetic
# - equity_PG_Chrono_Split_residuals_eGARCH_residuals_synthetic
# - equity_PG_TS_CV_residuals_eGARCH_residuals_synthetic
# - equity_WMT_Chrono_Split_residuals_eGARCH_residuals_synthetic
# - equity_WMT_TS_CV_residuals_eGARCH_residuals_synthetic
# - fx_EURUSD_Chrono_Split_residuals_eGARCH_residuals_synthetic
# - fx_EURUSD_TS_CV_residuals_eGARCH_residuals_synthetic
# - fx_EURZAR_Chrono_Split_residuals_eGARCH_residuals_synthetic
# - fx_EURZAR_TS_CV_residuals_eGARCH_residuals_synthetic
# - fx_GBPCNY_Chrono_Split_residuals_eGARCH_residuals_synthetic
# - fx_GBPCNY_TS_CV_residuals_eGARCH_residuals_synthetic
# - fx_GBPUSD_Chrono_Split_residuals_eGARCH_residuals_synthetic
# - fx_GBPUSD_TS_CV_residuals_eGARCH_residuals_synthetic
# - fx_GBPZAR_Chrono_Split_residuals_eGARCH_residuals_synthetic
# - fx_GBPZAR_TS_CV_residuals_eGARCH_residuals_synthetic
# - fx_USDZAR_Chrono_Split_residuals_eGARCH_residuals_synthetic
# - fx_USDZAR_TS_CV_residuals_eGARCH_residuals_synthetic
# - equity_AMZN_Chrono_Split_residuals_gjrGARCH_residuals_synthetic
# - equity_AMZN_TS_CV_residuals_gjrGARCH_residuals_synthetic
# - equity_CAT_Chrono_Split_residuals_gjrGARCH_residuals_synthetic
# - equity_CAT_TS_CV_residuals_gjrGARCH_residuals_synthetic
# - equity_MSFT_Chrono_Split_residuals_gjrGARCH_residuals_synthetic
# - equity_MSFT_TS_CV_residuals_gjrGARCH_residuals_synthetic
# - equity_NVDA_Chrono_Split_residuals_gjrGARCH_residuals_synthetic
# - equity_NVDA_TS_CV_residuals_gjrGARCH_residuals_synthetic
# - equity_PG_Chrono_Split_residuals_gjrGARCH_residuals_synthetic
# - equity_PG_TS_CV_residuals_gjrGARCH_residuals_synthetic
# - equity_WMT_Chrono_Split_residuals_gjrGARCH_residuals_synthetic
# - equity_WMT_TS_CV_residuals_gjrGARCH_residuals_synthetic
# - fx_EURUSD_Chrono_Split_residuals_gjrGARCH_residuals_synthetic
# - fx_EURUSD_TS_CV_residuals_gjrGARCH_residuals_synthetic
# - fx_EURZAR_Chrono_Split_residuals_gjrGARCH_residuals_synthetic
# - fx_EURZAR_TS_CV_residuals_gjrGARCH_residuals_synthetic
# - fx_GBPCNY_Chrono_Split_residuals_gjrGARCH_residuals_synthetic
# - fx_GBPCNY_TS_CV_residuals_gjrGARCH_residuals_synthetic
# - fx_GBPUSD_Chrono_Split_residuals_gjrGARCH_residuals_synthetic
# - fx_GBPUSD_TS_CV_residuals_gjrGARCH_residuals_synthetic
# - fx_GBPZAR_Chrono_Split_residuals_gjrGARCH_residuals_synthetic
# - fx_GBPZAR_TS_CV_residuals_gjrGARCH_residuals_synthetic
# - fx_USDZAR_Chrono_Split_residuals_gjrGARCH_residuals_synthetic
# - fx_USDZAR_TS_CV_residuals_gjrGARCH_residuals_synthetic
# - equity_AMZN_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic
# - equity_AMZN_TS_CV_residuals_sGARCH_norm_residuals_synthetic
# - equity_CAT_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic
# - equity_CAT_TS_CV_residuals_sGARCH_norm_residuals_synthetic
# - equity_MSFT_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic
# - equity_MSFT_TS_CV_residuals_sGARCH_norm_residuals_synthetic
# - equity_NVDA_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic
# - equity_NVDA_TS_CV_residuals_sGARCH_norm_residuals_synthetic
# - equity_PG_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic
# - equity_PG_TS_CV_residuals_sGARCH_norm_residuals_synthetic
# - equity_WMT_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic
# - equity_WMT_TS_CV_residuals_sGARCH_norm_residuals_synthetic
# - fx_EURUSD_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic
# - fx_EURUSD_TS_CV_residuals_sGARCH_norm_residuals_synthetic
# - fx_EURZAR_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic
# - fx_EURZAR_TS_CV_residuals_sGARCH_norm_residuals_synthetic
# - fx_GBPCNY_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic
# - fx_GBPCNY_TS_CV_residuals_sGARCH_norm_residuals_synthetic
# - fx_GBPUSD_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic
# - fx_GBPUSD_TS_CV_residuals_sGARCH_norm_residuals_synthetic
# - fx_GBPZAR_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic
# - fx_GBPZAR_TS_CV_residuals_sGARCH_norm_residuals_synthetic
# - fx_USDZAR_Chrono_Split_residuals_sGARCH_norm_residuals_synthetic
# - fx_USDZAR_TS_CV_residuals_sGARCH_norm_residuals_synthetic
# - equity_AMZN_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic
# - equity_AMZN_TS_CV_residuals_sGARCH_sstd_residuals_synthetic
# - equity_CAT_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic
# - equity_CAT_TS_CV_residuals_sGARCH_sstd_residuals_synthetic
# - equity_MSFT_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic
# - equity_MSFT_TS_CV_residuals_sGARCH_sstd_residuals_synthetic
# - equity_NVDA_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic
# - equity_NVDA_TS_CV_residuals_sGARCH_sstd_residuals_synthetic
# - equity_PG_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic
# - equity_PG_TS_CV_residuals_sGARCH_sstd_residuals_synthetic
# - equity_WMT_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic
# - equity_WMT_TS_CV_residuals_sGARCH_sstd_residuals_synthetic
# - fx_EURUSD_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic
# - fx_EURUSD_TS_CV_residuals_sGARCH_sstd_residuals_synthetic
# - fx_EURZAR_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic
# - fx_EURZAR_TS_CV_residuals_sGARCH_sstd_residuals_synthetic
# - fx_GBPCNY_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic
# - fx_GBPCNY_TS_CV_residuals_sGARCH_sstd_residuals_synthetic
# - fx_GBPUSD_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic
# - fx_GBPUSD_TS_CV_residuals_sGARCH_sstd_residuals_synthetic
# - fx_GBPZAR_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic
# - fx_GBPZAR_TS_CV_residuals_sGARCH_sstd_residuals_synthetic
# - fx_USDZAR_Chrono_Split_residuals_sGARCH_sstd_residuals_synthetic
# - fx_USDZAR_TS_CV_residuals_sGARCH_sstd_residuals_synthetic
# - equity_AMZN_Chrono_Split_residuals_TGARCH_residuals_synthetic
# - equity_AMZN_TS_CV_residuals_TGARCH_residuals_synthetic
# - equity_CAT_Chrono_Split_residuals_TGARCH_residuals_synthetic
# - equity_CAT_TS_CV_residuals_TGARCH_residuals_synthetic
# - equity_MSFT_Chrono_Split_residuals_TGARCH_residuals_synthetic
# - equity_MSFT_TS_CV_residuals_TGARCH_residuals_synthetic
# - equity_NVDA_Chrono_Split_residuals_TGARCH_residuals_synthetic
# - equity_NVDA_TS_CV_residuals_TGARCH_residuals_synthetic
# - equity_PG_Chrono_Split_residuals_TGARCH_residuals_synthetic
# - equity_PG_TS_CV_residuals_TGARCH_residuals_synthetic
# - equity_WMT_Chrono_Split_residuals_TGARCH_residuals_synthetic
# - equity_WMT_TS_CV_residuals_TGARCH_residuals_synthetic
# - fx_EURUSD_Chrono_Split_residuals_TGARCH_residuals_synthetic
# - fx_EURUSD_TS_CV_residuals_TGARCH_residuals_synthetic
# - fx_EURZAR_Chrono_Split_residuals_TGARCH_residuals_synthetic
# - fx_EURZAR_TS_CV_residuals_TGARCH_residuals_synthetic
# - fx_GBPCNY_Chrono_Split_residuals_TGARCH_residuals_synthetic
# - fx_GBPCNY_TS_CV_residuals_TGARCH_residuals_synthetic
# - fx_GBPUSD_Chrono_Split_residuals_TGARCH_residuals_synthetic
# - fx_GBPUSD_TS_CV_residuals_TGARCH_residuals_synthetic
# - fx_GBPZAR_Chrono_Split_residuals_TGARCH_residuals_synthetic
# - fx_GBPZAR_TS_CV_residuals_TGARCH_residuals_synthetic
# - fx_USDZAR_Chrono_Split_residuals_TGARCH_residuals_synthetic
# - fx_USDZAR_TS_CV_residuals_TGARCH_residuals_synthetic
#
# 📊 Metrics for fx_USDZAR_Chrono_Split_residuals_eGARCH_residuals_synthetic:
# KS Distance: 0.06669
# Wasserstein Distance: 0.00114
# Skewness (Real): -0.13198
# Skewness (Synthetic): -0.03004
# Kurtosis (Real): 0.54668
# Kurtosis (Synthetic): -0.02873
# array([0.0111035 , 0.00936287, 0.01664994, ..., 0.00743666, 0.00613614,
#        0.01649721], dtype=float32)
